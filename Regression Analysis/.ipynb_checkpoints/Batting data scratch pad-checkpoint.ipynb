# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, KFold

from sklearn.linear_model import LinearRegression, Lasso, LassoCV

# %%
batters_df = pd.read_csv('../DEA Notebooks/cleaned_batting_years_1985_to_2017.csv')

# %%
del batters_df['Unnamed: 0']

#create log salary to look at correlations
batters_df['LOG_SALARY'] = np.log(batters_df['SALARY'])

# %%
subset_to_test_with = batters_df[(batters_df.PA > 400)]
subset_to_test_with.shape
# Out:
# (6428, 50)

# %%
batters_df.columns
# Out:
# Index(['ID', 'NAME', 'HEIGHT', 'WEIGHT', 'YEAR', 'AGE', 'TM', 'LG', 'G', 'PA',
#        'AB', 'R', 'H', '2B', '3B', 'HR', 'RBI', 'SB', 'CS', 'BB', 'SO', 'BA',
#        'OBP', 'SLG', 'OPS', 'OPS+', 'TB', 'GDP', 'HBP', 'SH', 'SF', 'IBB',
#        'AWARDS', 'SALARY', 'BATS_Left', 'BATS_Right', 'LG_SALARY_YEAR',
#        'LG_SALARY_MEAN', 'POS_1', 'POS_2', 'POS_3', 'POS_4', 'POS_5', 'POS_6',
#        'POS_7', 'POS_8', 'POS_9', 'POS_D', 'HR_FREE_HITS', 'LOG_SALARY'],
#       dtype='object')

# %%
counting_stats = ['PA',
       'R', 'H', '2B', 'HR', 'RBI', 'SB', 'CS', 'BB', 'SO']
prob_stats = ['BA',
       'OBP', 'SLG', 'OPS', 'H','R']
physical_stats = ['AGE','HEIGHT','WEIGHT','BATS_Left','BATS_Right']
salary_stats = ['SALARY','LG_SALARY_YEAR']
position = ['POS_1', 'POS_2', 'POS_3', 'POS_4', 'POS_5', 'POS_6',
       'POS_7', 'POS_8', 'POS_9', 'POS_D']
f3 = ['AGE', 'OBP', 'SLG', 'HR', 'LG_SALARY_MEAN', 'RBI']

hr_f1 = ['AGE','WEIGHT', 'R', 'SB', 'CS', '3B', 'RBI', 'SB', 'CS', 'BB', 'SO', 'GDP', 'PA']

# %%
y_vars = 'HR'
x_vars = hr_f1
sns.pairplot(subset_to_test_with, x_vars=x_vars, y_vars=y_vars)

# %%
sns.heatmap(subset_to_test_with[x_vars + ['HR']].corr(), square=True, cmap='RdYlGn')

# %%
sns.distplot(subset_to_test_with['SALARY'])

# %%
sns.distplot(np.log(subset_to_test_with['SALARY']))

# %%
np.log(batters_df['SALARY'])
# Out:
# 0        14.741752
# 1        12.765688
# 2        12.676076
# 3        12.765688
# 4        13.141381
# 5        12.506177
# 6        12.206073
# 7        11.127263
# 8        12.691580
# 9        13.910821
# 10       12.301383
# 11       11.191342
# 12       11.042922
# 13       12.899220
# 14       12.847927
# 15       12.944623
# 16       15.201805
# 17       11.251561
# 18       11.599103
# 19       11.599103
# 20       12.429216
# 21       12.911642
# 22       11.599103
# 23       12.254863
# 24       14.115615
# 25       12.429216
# 26       12.388394
# 27       11.512925
# 28       11.599103
# 29       12.686954
#            ...
# 13738    14.430696
# 13739    13.592367
# 13740    13.166189
# 13741    15.652881
# 13742    11.775290
# 13743    14.968190
# 13744    13.815511
# 13745    14.731801
# 13746    13.728500
# 13747    14.690979
# 13748    14.586776
# 13749    13.217674
# 13750    14.938815
# 13751    12.807653
# 13752    16.654715
# 13753    15.617220
# 13754    15.564710
# 13755    13.122363
# 13756    16.791040
# 13757    15.501910
# 13758    14.992112
# 13759    16.341239
# 13760    14.827111
# 13761    15.424948
# 13762    13.815511
# 13763    15.687313
# 13764    15.291417
# 13765    14.871563
# 13766    14.936102
# 13767    15.894952
# Name: SALARY, Length: 13768, dtype: float64

# %%
batters_df[['NAME', 'YEAR', 'SALARY','INFLATION_ADJ_SALARY']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-5b5729e5efd3> in <module>()
# ----> 1 batters_df[['NAME', 'YEAR', 'SALARY','INFLATION_ADJ_SALARY']]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1956         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1957             # either boolean or fancy integer index
# -> 1958             return self._getitem_array(key)
#    1959         elif isinstance(key, DataFrame):
#    1960             return self._getitem_frame(key)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2000             return self.take(indexer, axis=0, convert=False)
#    2001         else:
# -> 2002             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2003             return self.take(indexer, axis=1, convert=True)
#    2004
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1229                 mask = check == -1
#    1230                 if mask.any():
# -> 1231                     raise KeyError('%s not in index' % objarr[mask])
#    1232
#    1233                 return _values_from_object(indexer)
#
# KeyError: "['INFLATION_ADJ_SALARY'] not in index"
